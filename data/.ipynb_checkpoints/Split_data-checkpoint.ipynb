# %%
import pandas as pd
import numpy as np
from random import sample

# %%
df = pd.read_csv('./wikitext-2/DVA_dataset.csv',header=None)

# %%
l = list(range(len(df)))

# %%
v1 = sample(l, 460)
l = list(set(l)-set(v1))
v2 = sample(l, 461)
l = list(set(l)-set(v2))
v3 = sample(l, 461)
l = list(set(l)-set(v3))
v4 = sample(l, 461)
l = list(set(l)-set(v4))
v5 = sample(l, 461)
l = list(set(l)-set(v5))

# %%
def split(df, v_index):
    test = df.ix[v_index]
    train = df.loc[~df.index.isin(v_index)]
    val = train.sample(58)
    train = train.loc[~train.index.isin(list(val.index))]
    return train, val, test

# %%
for i,v in enumerate([v1,v2,v3,v4,v5]):
    train, val, test = split(df, v)
    train.to_csv('train{}.csv'.format(i),header=None,index=False)
    val.to_csv('val{}.csv'.format(i),header=None,index=False)
    test.to_csv('test{}.csv'.format(i),header=None,index=False)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
df = pd.read_csv('./wikitext-2/cvaw4.csv')

# %%
for f in [0, 1, 2, 3, 4]:
    print('fold: {}'.format(f))
    train = pd.read_csv('train{}.csv'.format(f), header=None)
    test = pd.read_csv('test{}.csv'.format(f), header=None)
    val = pd.read_csv('val{}.csv'.format(f), header=None)
    for t in [train, test, val]:
        for i,s in enumerate([([w.split('(')[:-1][0] for w in i.split(' ')]) for i in t[1]]):
            index = []
            if len(set(s) & set(list(df['Word']))) >0:
                index.append(i)
# Out:
# fold: 0
# fold: 1
# fold: 2
# fold: 3
# fold: 4

# %%
# Out:
# [['快樂', '是', '我', '的', '奢侈品'],
#  ['由', '最初', '的', '焦慮症', '至', '憂鬱症'],
#  ['我', '不會', '悲傷', '也', '不會', '感動'],
#  ['沒有', '喜怒哀樂'],
#  ['生命', '及', '生活', '陷入', '黑白'],
#  ['不斷', '哭泣'],
#  ['不斷', '湧出', '的', '難過'],
#  ['又', '動不動', '的', '想', '哭', '的', '死去活來'],
#  ['常常', '會', '莫名', '的', '想', '哭'],
#  ['可是', '常常', '還是', '情緒', '莫名', '的', '低落'],
#  ['心情', '就', '跟', '著', '低落'],
#  ['有時', '會', '產生', '憂鬱', '的', '症狀'],
#  ['我', '好', '低潮'],
#  ['加上', '壓力', '和', '憂鬱'],
#  ['但', '情緒', '一直', '很', '低落'],
#  ['近來', '在', '工作', '上', '非常', '低落'],
#  ['但是', '他', '會', '感到', '非常', '難過'],
#  ['心情', '就', '會', '很', '不', '好'],
#  ['常常', '使得', '對', '自己', '很', '哀怨'],
#  ['要不然', '就是', '很', '低落'],
#  ['似乎', '擺', '脫不了', '人世間', '的', '悲哀'],
#  ['只是', '無緣', '由', '地', '沮喪', '難過'],
#  ['但', '情緒', '來', '時', '總', '無法', '控制'],
#  ['但', '我', '真的', '很', '掛念', '憂鬱'],
#  ['不', '想', '離開', '憂鬱'],
#  ['但', '會', '不停', '圍繞', '憂鬱', '思想'],
#  ['身邊', '的', '人', '心情', '不佳'],
#  ['現在', '每', '次', '憂鬱'],
#  ['大都', '是', '先', '憂鬱'],
#  ['我', '嘗試', '讓', '憂鬱', '自然', '的', '來'],
#  ['會', '乘機', '去', '憂鬱'],
#  ['而且', '我', '好', '難過'],
#  ['難過', '他們', '不', '去', '面對'],
#  ['會', '寂寞', '的', '想', '哭'],
#  ['好像', '憂鬱', '又', '像', '焦慮'],
#  ['自己', '也', '找不出', '低潮', '的', '原因'],
#  ['難過', '的', '時間', '持續', '很', '久'],
#  ['都', '會', '難過', '很', '久'],
#  ['自己', '會', '崩潰'],
#  ['都', '覺得', '難過'],
#  ['難過', '的', '想', '掉', '眼淚'],
#  ['常常', '會', '無端', '端', '就', '哭'],
#  ['會', '哭', '到', '不能', '自己'],
#  ['至今', '常常', '情緒', '低落', '無法', '專注', '工作'],
#  ['上班', '也', '難過'],
#  ['就是', '很', '喜歡', '流淚'],
#  ['心情', '沮喪', '不', '想', '上班'],
#  ['整', '個', '人像', '崩潰', '了', '一般'],
#  ['但', '我', '還是', '很', '難過'],
#  ['打', '過', '之後', '心情', '一直', '很', '差'],
#  ['常常', '心情', '低落'],
#  ['因', '無力', '改善', '心情'],
#  ['這', '令', '我', '十分', '傷心'],
#  ['以為', '痛苦', '已經', '過去'],
#  ['這', '一陣子', '容易', '感到', '寂寞', '及', '沮喪'],
#  ['常', '會', '無緣無故', '的', '哭'],
#  ['導致', '自己', '心情', '沮喪'],
#  ['期間', '情緒', '一', '度', '陷入', '低潮'],
#  ['睡不著', '一直', '哭'],
#  ['可', '我', '就是', '高興', '不', '起來'],
#  ['可是', '我', '就是', '快樂', '不', '起來'],
#  ['都', '不', '是', '很', '快樂'],
#  ['我', '已經', '不能', '快樂', '了'],
#  ['總是', '快樂', '不', '起來'],
#  ['會', '讓', '我', '不', '開心', '很', '久'],
#  ['我', '每', '天', '都', '無法', '快樂', '起來'],
#  ['無法', '體驗到', '各', '種', '快樂'],
#  ['也', '沒有', '任何', '快樂', '的', '事'],
#  ['常', '感到', '不', '開心'],
#  ['沒有', '任何', '事情', '可', '另', '我', '開心'],
#  ['常常', '不', '開心'],
#  ['經常', '不', '開心'],
#  ['也', '從來', '不', '笑'],
#  ['但是', '從來', '沒有', '感到', '快樂', '過'],
#  ['她', '的', '個性', '變', '的', '不', '開朗'],
#  ['我', '得不到', '快樂'],
#  ['沒辦法', '讓', '自己', '快樂'],
#  ['想', '快樂', '起來', '卻', '快樂', '不', '起來'],
#  ['我', '現在', '不', '太', '會', '笑'],
#  ['我', '每', '天', '都', '很', '不', '快樂'],
#  ['居然', '快樂', '不', '起來'],
#  ['也', '不', '知道', '何謂', '快樂'],
#  ['想到', '讓', '自己', '發病', '真', '是', '難過'],
#  ['覺得', '好', '痛苦'],
#  ['我', '覺得', '我', '很', '容易', '不', '快樂'],
#  ['心情', '會', '更', '不', '好'],
#  ['心情', '也', '沒', '變', '平緩'],
#  ['讓', '我', '整', '天', '心理', '都', '好', '難受'],
#  ['真的', '好', '痛苦'],
#  ['我', '常常', '覺得', '相當', '難過'],
#  ['心情', '越', '是', '糟糕'],
#  ['我', '真的', '很', '難過', '吧'],
#  ['沮喪', '等', '情緒', '起伏', '時'],
#  ['令', '我', '心情', '很', '不', '高興'],
#  ['只', '為了', '隱藏', '我', '的', '痛苦'],
#  ['回到', '家', '還', '會', '偷偷', '掉', '眼淚'],
#  ['看到', '自己', '不', '快樂', '不', '舒服'],
#  ['近日', '心情', '不', '好'],
#  ['常常', '想', '大叫', '或', '大哭'],
#  ['最近', '每天', '都', '很', '難過'],
#  ['無時無刻', '都', '會', '落淚'],
#  ['每', '天', '都', '以', '淚', '洗面'],
#  ['有時', '沒', '時', '就', '會', '覺得', '憂鬱'],
#  ['我', '的', '心靈', '好', '痛苦'],
#  ['莫名其妙', '的', '想', '哭'],
#  ['好像', '快', '變成', '憂鬱症', '了'],
#  ['心情', '不', '舒服'],
#  ['我', '就', '覺得', '很', '難過'],
#  ['只', '會', '不停', '哭泣'],
#  ['還', '痛苦', '的', '活', '著'],
#  ['冷不防', '的', '會', '突然', '情緒', '低落'],
#  ['從', '情緒', '極', '劇', '低落', '開始'],
#  ['沮喪', '想', '哭'],
#  ['但是', '低潮', '時', '會', '無法', '控制', '情緒'],
#  ['這', '種', '感覺', '很', '難受'],
#  ['憂鬱症', '又', '復發', '了'],
#  ['好', '痛苦', '又', '好', '累'],
#  ['有時', '難過', '的', '很', '悶', '很', '悶'],
#  ['最近', '兩', '個', '月', '中', '常常', '情緒', '低落'],
#  ['最近', '情緒', '又', '開始', '低落'],
#  ['除了', '因為', '沮喪'],
#  ['常常', '覺得', '很', '沮喪'],
#  ['最近', '我', '憂鬱', '越來越', '嚴重', '了'],
#  ['然後', '心情', '馬上', '低落'],
#  ['感覺', '很', '無助'],
#  ['反倒', '覺得', '難過'],
#  ['我', '很', '難過'],
#  ['常常', '一', '整', '天', '很', '憂鬱'],
#  ['隨著', '憂鬱', '變得', '悲觀'],
#  ['最近', '覺得', '自己', '越來越', '憂鬱'],
#  ['我們', '現在', '真的', '好', '難受', '喔'],
#  ['我', '好', '難過'],
#  ['悲傷', '不已'],
#  ['而且', '精神', '好像', '快要', '崩潰', '一樣'],
#  ['常常', '會', '覺得', '悲傷', '想', '哭'],
#  ['也', '容易', '傷心'],
#  ['也', '感覺', '很', '傷心'],
#  ['最近', '因', '心情', '不佳'],
#  ['一定', '也', '是', '一直', '哭'],
#  ['最近', '我', '又', '開始', '憂鬱', '了'],
#  ['心情', '不', '好', '的', '時後'],
#  ['我', '真的', '好', '無助'],
#  ['導致', '情緒', '低落'],
#  ['動不動', '就', '想', '哭'],
#  ['心情', '壓力', '很', '大', '而', '開始', '流淚'],
#  ['每', '天', '都', '很', '不', '快樂'],
#  ['我', '覺得', '很', '不', '快樂'],
#  ['情緒', '長期', '低落'],
#  ['莫名', '的', '哭泣'],
#  ['一', '年', '前', '一直', '不自覺', '地', '要', '流淚'],
#  ['因為', '這樣', '太', '痛苦', '了'],
#  ['我', '實在', '非常', '痛苦'],
#  ['這', '種', '日子', '真是', '難過'],
#  ['情緒', '越來越', '悲傷'],
#  ['而且', '很', '容易', '想', '哭'],
#  ['心情', '一直', '很', '差'],
#  ['覺得', '很', '難過'],
#  ['我', '覺得', '好', '難過'],
#  ['心情', '也', '很', '不', '好'],
#  ['有時', '會', '大叫', '大哭'],
#  ['而', '陷入', '悲傷', '的', '情緒', '中'],
#  ['我', '常常', '覺得', '我', '很', '不', '快樂'],
#  ['但', '真的', '我', '好', '難過'],
#  ['那', '種', '心痛'],
#  ['我', '就', '好', '想', '哭'],
#  ['然後', '心情', '生氣', '又', '難過'],
#  ['可是', '我', '很', '難過'],
#  ['只是', '很', '難過'],
#  ['都', '在', '沮喪', '哭泣', '中', '過日子', '了'],
#  ['因為', '我', '有', '幾', '次', '崩潰', '時'],
#  ['心情', '一下子', '跌落', '了', '谷底'],
#  ['感覺', '整', '個', '人', '快', '崩潰', '了'],
#  ['我', '並', '不', '快樂'],
#  ['最後', '我', '往往', '都', '是', '大哭'],
#  ['卻', '有', '陣子', '情緒', '低落'],
#  ['想', '哭', '哭', '不', '出來'],
#  ['好', '痛苦', '喔'],
#  ['也', '因', '我', '之前', '太', '痛苦'],
#  ['心理', '一直', '困擾', '著', '很', '沮喪'],
#  ['所以', '真的', '很', '難過'],
#  ['晚上', '睡覺', '時', '都', '覺得', '很', '悲傷'],
#  ['崩潰', '的', '哭', '到', '無法', '自主'],
#  ['可是', '感覺', '我', '還是', '一樣', '很', '憂鬱'],
#  ['每天', '晚上', '只', '能', '不斷', '的', '哭泣'],
#  ['我', '大哭', '到', '喘不', '過', '氣'],
#  ['還是', '很', '難過'],
#  ['他', '就', '會', '很', '難過'],
#  ['現在', '心情', '有點', '沮喪'],
#  ['好幾', '次', '面臨', '精神', '崩潰', '邊緣'],
#  ['有時', '悶悶不樂'],
#  ['而', '非常', '鬱悶'],
#  ['遇到', '挫折', '不', '順心', '老是', '愛', '哭'],
#  ['而且', '很', '不', '快樂'],
#  ['克制', '不', '住', '悲傷', '的', '情緒'],
#  ['我', '時常', '會', '情緒', '低落'],
#  ['甚至', '會', '無', '原', '無故', '的', '落淚'],
#  ['一直', '哭', '哭', '到', '死', '為止'],
#  ['突如其來', '的', '沮喪感', '無力感'],
#  ['好', '孤單', '無助'],
#  ['不過', '我', '現在', '深陷', '沮喪'],
#  ['越', '想', '越', '痛苦'],
#  ['我', '怕', '他們', '跟', '我', '一起', '崩潰'],
#  ['我', '有時', '會', '悶', '到', '哭出來'],
#  ['中度', '憂鬱症', '的', '症狀'],
#  ['最近', '我', '常常', '容易', '哭'],
#  ['然後', '就', '會', '很', '想', '哭', '一直', '哭'],
#  ['常常', '覺得', '情緒', '很', '低落'],
#  ['常常', '半夜', '起來', '哭'],
#  ['有時', '會', '不自主', '的', '大哭'],
#  ['隨時', '有', '崩潰', '的', '感覺'],
#  ['心情', '不', '太', '好'],
#  ['情緒', '低落'],
#  ['終日', '以', '淚', '洗面'],
#  ['我', '已經', '憂鬱', '一', '年', '半', '了'],
#  ['而且', '很', '悲哀'],
#  ['覺得', '非常', '非常', '地', '沮喪'],
#  ['我', '常常', '會', '心情', '低落'],
#  ['憂鬱', '頭昏'],
#  ['有時', '會', '難過', '到', '想', '自殺'],
#  ['常常', '感到', '情緒', '低落'],
#  ['每', '天', '以', '淚', '洗面'],
#  ['這', '讓', '我', '很', '沮喪'],
#  ['不能', '自制', '地', '哭泣'],
#  ['我', '現在', '真的', '好', '無助'],
#  ['每', '天', '工作', '時', '會', '覺得', '很', '憂鬱'],
#  ['但', '心', '中', '還是', '有', '些', '憂鬱'],
#  ['但', '有時', '沒', '吃', '會', '很', '憂鬱'],
#  ['沮喪', '怨天尤人'],
#  ['覺得', '很', '悲哀'],
#  ['有時', '又', '會', '無故', '低潮'],
#  ['久久', '抑鬱', '不', '樂'],
#  ['情緒', '有點', '低落'],
#  ['每每', '都', '讓', '我', '哭', '得', '不能', '自己'],
#  ['當', '我', '憂鬱', '時', '我', '想', '自殺'],
#  ['只', '知道', '她', '常常', '心情', '不', '好'],
#  ['心情', '低落', '悲傷'],
#  ['活', '著', '不', '快樂'],
#  ['心', '裡', '莫名其妙', '的', '難過'],
#  ['並且', '常常', '處於', '憂鬱', '的', '情形'],
#  ['覺得', '很', '傷心'],
#  ['心情', '一直', '都', '很', '差'],
#  ['我', '覺得', '十分', '沮喪'],
#  ['我', '發現', '我', '心情', '又', '不', '好了'],
#  ['這', '使', '我', '心情', '變', '的', '不', '好'],
#  ['眼淚', '不停', '的', '流'],
#  ['真是', '悲哀'],
#  ['心情', '莫名', '奇妙', '的', '低落'],
#  ['讓', '我', '在', '茫茫', '無助', '中'],
#  ['但', '我', '心理', '很', '憂鬱'],
#  ['接著', '就', '是', '很', '長', '時間', '的', '沮喪'],
#  ['我', '覺得', '好', '沮喪'],
#  ['但', '卻', '一點', '也', '不', '快樂'],
#  ['但', '憂鬱症', '卻', '常', '復發'],
#  ['真的', '很', '無助'],
#  ['忍不住', '就', '大哭', '了'],
#  ['但', '她', '仍', '是', '非常', '憂鬱'],
#  ['獨自', '無奈', '的', '嚎啕大哭'],
#  ['為', '此', '而', '心情', '難過'],
#  ['心情', '越', '難過'],
#  ['但是', '我', '心情', '一直', '很', '不', '好'],
#  ['她', '總是', '說', '她', '不', '快樂'],
#  ['但', '確', '顯得', '情緒', '低落'],
#  ['家人', '們', '都', '覺得', '很', '無助'],
#  ['每', '天', '十分', '難受'],
#  ['無端', '地', '想', '哭'],
#  ['有', '些', '沮喪'],
#  ['難過', '的', '事情數', '都', '數不清'],
#  ['很', '是', '難受'],
#  ['我', '覺得', '很', '無助'],
#  ['常常', '會', '自怨自艾'],
#  ['有時候', '睡', '到', '夜半', '也', '會', '忽然', '難過'],
#  ['有時', '連', '我', '都', '快', '崩潰', '了'],
#  ['常常', '無', '原', '由', '的', '想', '哭'],
#  ['剎那間', '我', '心', '裡', '好', '難過'],
#  ['就', '會', '心情', '低落'],
#  ['每每', '都', '悲從中來', '泣不成聲'],
#  ['心情', '超級', '鬱悶'],
#  ['我', '不', '快樂'],
#  ['而', '我', '心', '裡', '難過', '無法', '發洩'],
#  ['想到', '悲從中來', '時', '會', '落淚'],
#  ['幾', '次', '還', '隱泣', '痛哭'],
#  ['傷心', '落淚'],
#  ['因此', '她', '會', '更加', '傷心'],
#  ['現在', '時常', '覺得', '很', '沮喪'],
#  ['常常', '莫名其妙', '的', '想', '哭'],
#  ['心情', '一樣', '低落'],
#  ['常', '處於', '憂鬱', '狀態'],
#  ['我', '很', '不', '快樂'],
#  ['有時', '偷哭'],
#  ['都', '會', '偷偷', '的', '哭泣'],
#  ['我', '快', '崩潰', '了'],
#  ['從', '活潑', '變成', '憂鬱', '不能', '克制'],
#  ['心情', '跌落', '谷底'],
#  ['不知不覺', '的', '流下', '淚水'],
#  ['這', '感覺', '好', '難受'],
#  ['生活', '中', '常', '感到', '突然', '地', '沮喪'],
#  ['無由', '地', '要', '哭泣'],
#  ['想到', '傷心', '事', '會', '不斷', '哭泣'],
#  ['真的', '是', '很', '難受'],
#  ['整', '天', '躺', '在', '床', '上', '哭'],
#  ['這', '讓', '我', '心情', '時時', '很', '低落'],
#  ['似乎', '心情', '永遠', '好不', '起來', '一樣'],
#  ['會', '莫名其妙', '的', '掉', '眼淚'],
#  ['就', '哭', '著', '入睡'],
#  ['所以', '心情', '很', '難', '好', '起來'],
#  ['每', '天', '情緒', '都', '很', '低落'],
#  ['我', '好', '矛盾', '也好', '痛苦'],
#  ['好', '苦', '好', '累', '好', '灰心'],
#  ['實在', '很', '難過'],
#  ['心情', '也', '不', '開朗'],
#  ['現在', '我', '彷彿', '快要', '崩潰', '了'],
#  ['令', '我', '很', '沮喪'],
#  ['卻', '仍', '整', '日', '以', '淚', '洗面'],
#  ['我', '真是', '覺得', '好', '痛苦'],
#  ['心情', '就', '會', '很', '糟'],
#  ['這', '兩', '個', '星期', '很', '難過'],
#  ['自己', '一直', '覺得', '相當', '傷心'],
#  ['不然', '就是', '不停', '的', '哭泣'],
#  ['心', '中', '又', '有', '說', '不', '出', '來', '的', '哀傷'],
#  ['常', '期', '的', '情緒', '低落'],
#  ['常常', '莫名', '的', '情緒', '低落'],
#  ['我', '真的', '好', '難受'],
#  ['我', '好', '痛苦'],
#  ['真的', '心情', '鬱悶'],
#  ['我', '很', '無助'],
#  ['仍然', '常', '哭'],
#  ['我', '好', '想', '哭', '哦'],
#  ['活', '得', '好', '痛苦', '喔'],
#  ['覺得', '好', '無奈'],
#  ['十分', '無奈'],
#  ['有點', '無奈'],
#  ['我們', '全', '家', '都', '感到', '十分', '無奈'],
#  ['卻', '難免', '顯出', '我', '的', '無奈'],
#  ['總是', '對', '自身', '情況', '感覺', '無奈'],
#  ['感到', '無奈'],
#  ['除了', '生氣', '和', '無奈'],
#  ['我', '的', '不', '開心', '變成', '妒忌', '心'],
#  ['我', '經常', '對', '任何', '事', '悲觀'],
#  ['看', '世界', '太', '悲觀', '消極'],
#  ['心情', '也', '不', '開朗'],
#  ['卻', '有', '著', '悲觀', '無比', '的', '心'],
#  ['這', '種', '期待', '開始', '絕望', '了'],
#  ['絕望', '的', '情緒'],
#  ['幾近', '絕望'],
#  ['當時', '的', '我', '很', '害怕', '絕望'],
#  ['我', '開始', '感到', '絕望'],
#  ['對', '人生', '已', '感到', '絕望'],
#  ['一', '次', '一', '次', '的', '絕望'],
#  ['常常', '想到', '絕望', '害怕'],
#  ['心情', '真的', '很', '亂'],
#  ['不過', '我', '的', '心情', '頗', '飄忽不定', '的'],
#  ['心情', '的', '起伏', '非常', '大'],
#  ['心情', '無法', '平靜下來'],
#  ['但', '心情', '仍', '找', '不', '到', '平靜'],
#  ['心情', '一直', '在', '轉變'],
#  ['心情', '飄忽', '令', '我', '感到', '不易', '適應'],
#  ['忽然', '心情', '波動'],
#  ['心情', '一直', '很', '煩悶'],
#  ['憂鬱', '時', '心情', '煩悶'],
#  ['家人', '不', '在', '覺得', '孤單'],
#  ['讓', '我', '覺得', '很', '孤單'],
#  ['覺得', '很', '孤單'],
#  ['我', '感到', '很', '孤獨'],
#  ['可能', '孤獨', '的', '過', '一生'],
#  ['和', '我', '經常', '感', '寂寞'],
#  ['我', '很', '怕', '孤獨', '寂寞', '和', '黑夜'],
#  ['感覺', '好', '寂寞'],
#  ['雖然', '孤單'],
#  ['我', '真的', '很', '孤獨'],
#  ['覺得', '自己', '更', '孤單', '了'],
#  ['非常', '非常', '孤單', '的', '感覺'],
#  ['但', '我', '的', '心靈', '總是', '空虛', '的'],
#  ['心', '裡', '充滿', '空虛'],
#  ['掛完', '電話', '後', '空虛'],
#  ['我', '卻', '覺得', '很', '空虛'],
#  ['昨天', '空虛', '的'],
#  ['我', '人緣', '不錯', '但', '很', '空虛'],
#  ['我', '越來越', '覺得', '我', '好', '空虛'],
#  ['覺得', '很', '空虛'],
#  ['其實', '我', '好', '悶'],
#  ['從', '大一', '開始', '會', '覺得', '胸口', '鬱悶'],
#  ['胸口', '鬱悶'],
#  ['胸口', '很', '悶'],
#  ['常常', '想起', '就', '覺', '心頭', '悶'],
#  ['我', '的', '感覺', '常常', '感到', '很', '悶'],
#  ['就', '總', '覺得', '悶'],
#  ['很', '空虛', '至於', '衝動', '的', '行為'],
#  ['意志', '消沉'],
#  ['我', '又', '再', '消沉'],
#  ['自暴自棄'],
#  ['心情', '一直', '都', '很', '沉重'],
#  ['不', '想', '看', '他', '那麼', '消沉'],
#  ['卻', '又', '愈來愈', '消沈'],
#  ['想法', '極度', '的', '消極'],
#  ['現在', '的', '我', '對', '生活', '好', '消極'],
#  ['丈夫', '是', '個', '很', '消極', '的', '人'],
#  ['變得', '消極', '的', '極端', '自我'],
#  ['說話', '很', '消極'],
#  ['真的', '令', '我', '感到', '很', '灰心'],
#  ['令', '我', '感到', '灰心'],
#  ['覺得', '很', '累', '很', '灰心'],
#  ['現在', '我', '有', '種', '很', '孤單', '的', '感覺'],
#  ['讓', '我', '感到', '很', '孤單'],
#  ['覺得', '好', '孤獨'],
#  ['顯', '的', '落寞', '孤單'],
#  ['刻', '的', '感到', '孤獨'],
#  ['因此', '一', '個人', '孤單', '在', '外'],
#  ['你', '知道', '我', '有', '多', '孤單', '嗎'],
#  ['我', '可能', '是', '有點', '孤單', '吧'],
#  ['我', '總', '覺得', '我', '很', '苦命'],
#  ['有', '愛撫', '行為', '很', '對不起', '他'],
#  ['有', '種', '對不起', '現在', '男朋友', '的', '感覺'],
#  ['又', '覺得', '這樣', '會', '對不起', '媽媽'],
#  ['覺得', '對不起', '很多', '人'],
#  ['怪', '自己', '教', '不', '好'],
#  ['深表', '懺悔'],
#  ['撕碎', '紙張', '事', '後', '又', '後悔'],
#  ['又', '開始', '後悔'],
#  ['但是', '事', '後', '又', '會', '覺得', '後悔'],
#  ['但', '我', '會', '一輩子', '後悔', '的'],
#  ['但是', '事', '後', '我', '又', '會', '後悔'],
#  ['可是', '之後', '又', '後悔', '的', '要', '死'],
#  ['但', '事', '後', '又', '覺', '的', '後悔'],
#  ['現在', '我', '反而', '後悔', '了'],
#  ['很', '後悔', '做', '了', '這', '份', '工作'],
#  ['我', '只', '會', '拖累', '別人'],
#  ['我', '不能', '這樣子', '我', '會', '拖累', '大家'],
#  ['拖累', '家人', '我', '很', '難過'],
#  ['或是', '造成', '別人', '的', '困擾'],
#  ['有時', '覺得', '愧疚'],
#  ['還', '會', '因而', '產生', '愧疚感'],
#  ['聽到', '這些', '話', '我', '好', '愧疚', '喔'],
#  ['我', '依然', '很', '愧疚'],
#  ['我', '萬般', '愧疚'],
#  ['這', '令', '我', '感到', '很', '內疚'],
#  ['也', '伴有', '罪惡感'],
#  ['罪惡感', '不斷', '不斷', '加深'],
#  ['但', '沒', '上班', '又', '會', '有', '罪惡感'],
#  ['會', '有', '罪惡感'],
#  ['過多', '的', '罪惡感'],
#  ['感到', '非常', '的', '罪惡感'],
#  ['心', '中', '有', '極', '深', '的', '罪惡感'],
#  ['我', '更', '覺得', '罪惡感'],
#  ['時時', '有', '罪惡感', '的', '感覺'],
#  ['不知不覺', '的', '自責'],
#  ['因此', '非常', '自責'],
#  ['且', '自責', '不已'],
#  ['對', '自己', '不能', '停止', '的', '自責'],
#  ['使得', '自責', '愈', '深'],
#  ['心', '裡', '非常', '自責'],
#  ['我', '很', '自責'],
#  ['說', '一些', '自責', '的', '話'],
#  ['誰', '死', '便', '得', '幸福'],
#  ['死生', '早已', '置之度外', '了'],
#  ['只是', '至今', '賴活', '著'],
#  ['我', '不', '想', '這樣', '活', '著'],
#  ['我', '早', '就', '離開', '了'],
#  ['我', '就', '可以', '走', '了'],
#  ['因為', '覺得', '活', '著', '毫無', '意義'],
#  ['覺得', '人生', '已', '沒', '什麼', '意義'],
#  ['漸漸', '覺得', '人', '生出來', '應該', '死'],
#  ['對', '人生', '已', '感到', '絕望'],
#  ['活', '著', '只是', '拖時間', '罷了'],
#  ['感到', '活', '著', '沒有', '什麼', '意思'],
#  ['人生', '真的', '沒有', '什麼', '意思'],
#  ['覺得', '生活', '沒', '意義'],
#  ['不', '知道', '活', '著', '有', '什麼', '意義'],
#  ['我', '不', '知道', '我', '該', '怎麼', '活下去'],
#  ['找', '不', '到', '活下去', '的', '理由'],
#  ['自己', '沒有', '生存', '價值'],
#  ['覺得', '自己', '活', '的', '很', '沒', '價值'],
#  ['到底', '活', '著', '是', '為了', '什麼'],
#  ['也', '不', '懂', '究竟', '為什麼', '而', '活'],
#  ['但', '現實', '好', '無力', '有時', '心理', '想不開'],
#  ['也', '經常', '想不開'],
#  ['老是', '想不開'],
#  ['我', '甚至', '擔心', '她', '會', '想不開'],
#  ['我', '不', '需要', '生存'],
#  ['但', '不', '喜歡', '生存'],
#  ['本來', '就', '不', '該', '存在', '世界', '上'],
#  ['我', '也', '痛恨', '生命'],
#  ['人生', '很', '無趣'],
#  ['為何', '人生', '變得', '如此', '無趣'],
#  ['常常', '會', '覺得', '人生', '已經', '沒有', '意義'],
#  ['但', '活', '著', '真的', '很', '苦'],
#  ['生存', '還是', '很', '痛苦'],
#  ['令', '我', '覺得', '生命', '好', '苦'],
#  ['可是', '有時候', '就是', '活', '的', '累'],
#  ['還', '有', '心情', '不', '穩', '就', '會', '傷害', '自己'],
#  ['有時', '甚至', '會', '想', '傷害', '自己'],
#  ['有', '傷害', '自己', '的', '可能'],
#  ['便', '想', '自我', '了斷'],
#  ['甚至', '自己', '傷害', '自己'],
#  ['以及', '自虐', '的', '狀況'],
#  ['割', '腕', '或是', '拿', '刀', '刺', '心臟'],
#  ['而', '拿', '刀子', '割', '自己', '的', '手'],
#  ['行為', '失控', '拿', '刀', '自傷'],
#  ['我', '隔', '天吞藥', '自殺'],
#  ['常', '覺得', '人生', '沒', '意義'],
#  ['用', '頭', '猛撞', '牆'],
#  ['她', '可', '從', '然', '就', '死'],
#  ['寧可', '一', '覺', '不', '醒'],
#  ['就', '會', '拿', '刀', '自傷'],
#  ['自傷', '的', '行為', '還是', '一直', '斷斷續續', '存在'],
#  ['甚至', '連', '生命', '都', '可以', '給', '他'],
#  ['人生', '的', '意義', '何在'],
#  ['去年', '在', '醫師', '面前', '割', '腕'],
#  ['我', '有時', '想不開', '都', '會', '想', '自殺'],
#  ['覺得', '人', '活', '著', '有', '何', '意思'],
#  ['為什麼', '不', '早一點', '死'],
#  ['但', '只', '畫', '頭', '而', '沒有', '手'],
#  ['有', '厭世', '的', '傾向'],
#  ['我', '真的', '想', '自殺'],
#  ['我', '還是', '有', '自殺', '的', '念頭'],
#  ['她', '之前', '常常', '想到', '要', '自殺'],
#  ['昨天', '還', '說', '他', '想要', '自殺'],
#  ['會', '煩躁', '的', '想', '死掉', '算了'],
#  ['我', '常常', '想', '著', '去', '死'],
#  ['我', '便', '可以', '自殺'],
#  ['總', '覺得', '人生', '很', '沒', '意義'],
#  ['居然', '自殺'],
#  ['其實', '我', '真的', '不', '想', '生存'],
#  ['甚至', '想', '自殺'],
#  ['我', '有', '想', '過', '要', '自殺'],
#  ['也', '曾', '想', '過', '自殺'],
#  ['真', '想', '一', '死', '百', '了'],
#  ['想', '死', '而', '去', '看診'],
#  ['這樣', '就', '不', '算', '自殺', '了'],
#  ['就', '會', '很', '想', '自殺'],
#  ['好', '想', '一', '死', '百', '了'],
#  ['我', '真的', '要', '去', '自殺', '了'],
#  ['他', '嘗試', '自殺', '三', '次'],
#  ['常常', '會', '想到', '自殺', '的', '畫面'],
#  ['常', '有', '想不開', '的', '念頭'],
#  ['常', '感到', '不要', '活', '著'],
#  ['以前', '有', '過', '自殘', '的', '經驗'],
#  ['好', '想', '自殺', '喔'],
#  ['很', '想', '結束', '生命'],
#  ['不', '知道', '有', '多少', '次', '想', '死'],
#  ['我', '已經', '開始', '在', '計劃', '死亡', '了'],
#  ['我', '想要', '以', '死', '解決', '這', '一切'],
#  ['我', '好', '想', '死'],
#  ['常常', '想', '自殺', '做', '了結'],
#  ['我', '一定', '會', '選擇', '自殺'],
#  ['我', '好', '想', '一了百了'],
#  ['我', '就', '有', '自殺', '的', '念頭'],
#  ['我', '已經', '好幾', '次', '想', '自殺'],
#  ['好幾', '次', '想', '死'],
#  ['真', '想', '死掉', '算了'],
#  ['好', '想', '去', '死'],
#  ['半夜', '跑到', '外面', '去', '拿', '刀子', '自殺'],
#  ['最近', '的', '我', '一直', '想', '自殺'],
#  ['便', '會', '想', '死'],
#  ['有', '想', '自殘', '的', '念頭'],
#  ['我', '沒有', '一', '天', '不', '想', '自殺'],
#  ['還', '幾', '次', '想', '嘗試', '自殺'],
#  ['我', '真的', '很', '想', '死'],
#  ['我', '現在', '很', '強烈', '的', '想', '死'],
#  ['我', '已', '有', '數不清', '的', '自殺', '紀錄'],
#  ['我', '有', '嚴重', '的', '自殘', '傾向'],
#  ['有', '想', '自殺', '的', '念頭'],
#  ['很', '想', '自我', '了斷'],
#  ['曾', '有', '過', '自殺', '的', '念頭'],
#  ['我', '幾乎', '天天', '想', '自殺'],
#  ['甚至', '到', '了', '想', '自殺'],
#  ['要是', '不成', '我', '就', '得', '自殺', '了'],
#  ['我', '想', '我', '死', '了'],
#  ['想到', '用', '死', '解脫'],
#  ['甚至', '想要', '自殺'],
#  ['可是', '我', '還是', '想', '死'],
#  ['我', '不時', '會', '想到', '自殺', '了結', '一切'],
#  ['連', '想', '自殺', '時'],
#  ['當', '我', '憂鬱', '時', '我', '想', '自殺'],
#  ['輕生', '的', '念頭', '不', '的', '泛起'],
#  ['有時候', '會', '有', '自殺', '的', '念頭'],
#  ['嚴重', '時', '想到', '自殺'],
#  ['也', '曾', '說', '要', '自殺'],
#  ['曾', '講', '過', '想', '自殺'],
#  ['打算', '自殺', '時', '用'],
#  ['曾', '想', '自殺'],
#  ['會', '想', '自殺'],
#  ['我', '有時', '真', '覺得', '死', '了', '算了'],
#  ['她', '早', '就', '自殺', '了'],
#  ['有時', '會', '有', '輕生', '的', '念頭'],
#  ['想', '自殺', '或', '殺人'],
#  ['想', '了結', '自己', '的', '生命'],
#  ['開始', '有', '自殘', '的', '傾向'],
#  ['嚴重', '時', '甚至', '想要', '自殺'],
#  ['有', '自殺', '的', '念頭'],
#  ['我', '很', '想', '自殺'],
#  ['會', '一直', '想', '自殺'],
#  ['只是', '很', '想', '死'],
#  ['那時', '我', '真的', '想', '死'],
#  ['我', '想', '過', '要', '自殺'],
#  ['有時候', '母親', '說', '她', '想', '死'],
#  ['我', '很', '想', '死'],
#  ['我', '常', '有', '自殺', '的', '念頭'],
#  ['只', '知道', '很', '想', '死'],
#  ['可是', '又', '很', '想', '死'],
#  ['他', '想', '帶', '著', '孩子', '自殺'],
#  ['就', '想', '自殺', '或', '想', '殺人'],
#  ['我', '也', '曾', '自殺', '多', '次'],
#  ['我', '想', '自殺'],
#  ['甚至', '因此', '失眠'],
#  ['自覺', '無法', '入眠'],
#  ['甚至', '晚上', '作夢', '被', '驚嚇', '醒'],
#  ['他', '晚上', '就', '會', '睡', '不著'],
#  ['既', '不能', '入睡'],
#  ['每', '天', '睡覺', '都', '睡', '不好'],
#  ['我', '就', '會', '焦慮', '得', '睡不著覺'],
#  ['才', '能', '入睡'],
#  ['但', '就', '是', '睡覺', '時', '會', '焦慮'],
#  ['時常', '睡不', '著'],
#  ['所以', '睡眠', '品質', '一直', '很', '差'],
#  ['躺', '到', '床', '上', '卻', '又', '睡', '不著'],
#  ['一', '睡', '就是', '做', '惡夢'],
#  ['總是', '哭', '著', '醒來'],
#  ['二', '點', '才', '入睡'],
#  ['睡眠', '不好'],
#  ['我', '都', '會', '惡夢'],
#  ['最近', '睡眠', '好像', '不', '是', '很', '好'],
#  ['晚上', '睡', '不', '著想', '什麼', '也', '不一定'],
#  ['最近', '晚上', '都', '不', '好睡'],
#  ['有時', '半夜', '就', '醒來', '才', '又', '睡'],
#  ['睡', '也', '睡', '不好'],
#  ['偶爾', '會', '失眠'],
#  ['夜晚', '要', '不', '失眠'],
#  ['因為', '睡不', '著'],
#  ['睡不著', '一直', '哭'],
#  ['我', '變得', '很', '難', '入睡'],
#  ['他', '說', '他', '睡', '不著'],
#  ['但', '就是', '睡不', '著'],
#  ['為什麼', '一直', '難以', '入眠'],
#  ['我', '還是', '一樣', '晚上', '做', '惡夢', '睡', '不好'],
#  ['以致', '壓力', '大', '到', '睡眠', '障礙'],
#  ['睡眠', '中斷', '之後'],
#  ['我', '就', '會', '一直', '在', '做夢'],
#  ['且', '睡覺', '時', '易', '作夢'],
#  ['卻', '遲遲', '無法', '入睡', '之際'],
#  ['天天', '失眠'],
#  ['約', '一', '個', '星期', '失眠'],
#  ['考試', '老是', '緊張', '到', '睡不著覺'],
#  ['每', '天', '起床', '都', '好', '心慌'],
#  ['四', '點', '後', '才', '能', '上床', '睡'],
#  ['更', '常', '失眠'],
#  ['而且', '也', '常', '做', '惡夢'],
#  ['但', '仍', '擺', '脫不了', '惡夢'],
#  ['就是', '不', '肯', '睡'],
#  ['加上', '每', '晚', '駭人', '的', '惡夢'],
#  ['容易', '失眠'],
#  ['三', '年', '沒', '睡', '好了'],
#  ['影響', '我', '的', '睡眠'],
#  ['但', '最近', '常', '做夢'],
#  ['而且', '很多', '是', '惡夢'],
#  ['而且', '都', '會', '比', '平常', '早起'],
#  ['會', '很', '早', '醒來'],
#  ['約', '五', '點', '多', '醒來', '就', '睡不', '著'],
#  ['也', '睡', '不好'],
#  ['那', '陣子', '無法', '入睡'],
#  ['卻', '依然', '失眠'],
#  ['每', '晚', '睡覺', '都', '會', '作夢'],
#  ['晚上', '常', '睡', '不著'],
#  ['可是', '反而', '導致', '睡', '不著'],
#  ['反而', '一', '興奮', '就', '又', '醒來', '了'],
#  ['因而', '導致', '失眠'],
#  ['大概', '輾轉', '難', '眠'],
#  ['考試', '前', '睡不', '好', '的', '情形'],
#  ['失眠', '的', '情形', '又', '會', '再度', '發生'],
#  ['也', '是', '整', '夜', '失眠'],
#  ['但是', '失眠', '總是', '無法', '離開', '我'],
#  ['我', '睡覺', '的', '時候', '會', '磨牙'],
#  ['簡直', '有', '睡', '沒', '睡', '一樣'],
#  ['半夜', '常常', '驚醒'],
#  ['醒來', '後', '滿', '臉', '是', '淚'],
#  ['最近', '一直', '失眠'],
#  ['突然', '停藥', '是否', '會', '再度', '失眠'],
#  ['失眠', '已經', '長達', '兩', '年'],
#  ['無法', '入睡'],
#  ['甚至', '會', '無法', '入睡'],
#  ['幾乎', '晚上', '都', '睡', '不著'],
#  ['她', '就', '會', '醒來'],
#  ['我', '已經', '失眠', '有', '兩', '年', '以上'],
#  ['整', '晚', '無法', '入睡', '也', '無法', '控制'],
#  ['或', '完全', '不能', '入睡'],
#  ['失眠', '極度', '無', '安全感'],
#  ['想', '的', '只是', '為什麼', '她', '睡', '不著'],
#  ['開始', '有', '較', '明顯', '的', '失眠', '問題'],
#  ['便', '一直', '有', '難以', '入睡', '的', '問題'],
#  ['入睡', '前', '頻尿', '純粹', '是', '擔心', '睡', '不', '著'],
#  ['熟睡', '二三', '小時', '就', '會', '起床'],
#  ['她', '無法', '好好', '的', '睡覺'],
#  ['也', '影響到', '我們', '的', '睡眠'],
#  ['入眠', '很', '困難'],
#  ['一直', '失眠'],
#  ['所以', '失眠', '愈來愈', '嚴重'],
#  ['最近', '常常', '難', '入睡'],
#  ['由於', '連續', '沒', '睡好'],
#  ['我', '只要', '睡覺', '一定', '會', '做夢'],
#  ['最近', '已', '感到', '影響', '睡眠', '品質'],
#  ['我', '常常', '失眠'],
#  ['就', '幾乎', '沒', '睡', '好過'],
#  ['一', '個人', '晚上', '睡', '不著'],
#  ['只', '是', '因為', '她', '無法', '睡'],
#  ['睡眠', '亂七八糟'],
#  ['比', '以前', '早起'],
#  ['因此', '我', '失眠'],
#  ['嚴重', '失眠'],
#  ['每天', '凌晨', '四', '點', '才', '睡'],
#  ['同樣', '的', '惡夢', '又', '再度', '侵襲', '我'],
#  ['早上', '大約', '三四時', '才', '睡覺'],
#  ['夜裡', '常常', '難以', '入眠'],
#  ['睡眠', '雖', '難以', '入眠'],
#  ['我', '每', '天', '都', '失眠'],
#  ['只', '是', '晚上', '會', '睡', '不著'],
#  ['一下', '睡', '一下', '醒'],
#  ['或是', '睡不', '著'],
#  ['連', '服用', '安眠藥', '都', '睡', '不著'],
#  ['不', '是', '失眠', '就', '是', '睡', '得', '特別', '多'],
#  ['去年', '突然', '晚上', '睡不', '著'],
#  ['無法', '真正', '入睡', '即', '無法', '休息'],
#  ['到', '了', '無法', '睡覺'],
#  ['但', '早', '醒', '的', '話'],
#  ['有時', '過', '一下子', '會', '繼續', '入睡'],
#  ['但', '有時', '常常', '就', '睡', '不著', '了'],
#  ['四', '點', '才', '睡', '六', '點', '醒來'],
#  ['不', '讓', '我', '睡覺', '沒關係'],
#  ['常常', '晚上', '失眠'],
#  ['而且', '終夜', '無法', '成眠'],
#  ['感覺', '很', '累', '卻', '睡不', '著'],
#  ['無法', '就', '睡'],
#  ['我', '最近', '每晚', '都', '失眠'],
#  ['尤其', '睡眠', '不安'],
#  ['晚上', '睡覺', '時', '會', '磨牙'],
#  ['常', '會', '失眠'],
#  ['長期', '失眠'],
#  ['睡眠', '不', '安穩'],
#  ['那', '一陣子', '早上', '都', '被', '嚇醒'],
#  ['我', '睡', '得', '並', '不', '安穩'],
#  ['母親', '常常', '失眠'],
#  ['睡眠', '的', '品質', '也', '很', '差'],
#  ['有時候', '睡', '到', '夜半', '也', '會', '忽然', '難過'],
#  ['晚上', '睡不', '好', '也', '就', '罷了'],
#  ['清晨', '還', '會', '突然', '醒來'],
#  ['晚上', '睡不', '著'],
#  ['必需', '籍酒', '才', '能', '入睡'],
#  ['而且', '常', '作', '惡夢'],
#  ['理由', '是', '喝醉', '可以', '好', '入睡'],
#  ['就', '常', '為', '失眠', '所', '擾'],
#  ['也', '常', '抱怨', '睡', '不', '著'],
#  ['我', '還', '會', '徹夜', '難', '眠'],
#  ['晚上', '不易', '入睡'],
#  ['又', '常', '聽說', '為', '此', '常', '失眠'],
#  ['不易', '入睡'],
#  ['而', '睡眠', '也', '大', '不如', '從前'],
#  ['之後', '我', '幾乎', '每', '天', '都', '睡', '不好'],
#  ['長期', '的', '失眠'],
#  ['有時', '引起', '失眠'],
#  ['為了', '這', '件', '事情', '又', '失眠', '了'],
#  ['一旦', '入睡', '後', '就', '開始', '作夢'],
#  ['我', '會', '莫名', '恐懼', '失眠'],
#  ['最近', '又', '開始', '睡眠', '不', '正常'],
#  ['晚上', '更', '是', '為', '惡夢', '所', '擾'],
#  ['又', '嚴重', '的', '失眠'],
#  ['然後', '我', '就', '開始', '睡', '不著'],
#  ['又', '失眠', '了'],
#  ['一天到晚', '失眠'],
#  ['失眠', '都', '未', '改善'],
#  ['就', '睡不著覺'],
#  ['但是', '晚上', '睡不', '好'],
#  ['全', '身', '也', '感覺', '不', '舒服', '也', '睡', '不著'],
#  ['常', '在', '夢', '中', '流淚'],
#  ['睡眠', '品質', '不佳'],
#  ['沒有', '睡', '過', '好', '覺'],
#  ['每', '晚', '一定', '會', '做夢'],
#  ['而', '真的', '哭倒', '醒'],
#  ['就', '會', '獨自', '留在', '家', '中'],
#  ['起', '躲', '在', '家', '中'],
#  ['都', '悶', '在', '家', '裡'],
#  ['我', '整天', '躲', '在', '家', '裡'],
#  ['只', '想', '一輩子', '待在', '家', '裡'],
#  ['我', '現在', '也', '都', '不', '喜歡', '出門'],
#  ['我', '誰', '都', '不', '想見'],
#  ['根本', '連', '門', '都', '不', '想', '出去'],
#  ['大概', '一', '星期', '也', '不會', '出門'],
#  ['同學', '找', '我', '也', '不', '想', '出去'],
#  ['成天', '把', '自己', '關', '在', '房間', '裡'],
#  ['畢業', '後', '一直', '待在', '家', '裡'],
#  ['不', '願', '出門'],
#  ['不', '喜歡', '出門'],
#  ['只是', '不', '喜歡', '出門'],
#  ['不', '出門', '不', '跟', '任何', '人', '聯絡'],
#  ['但', '我', '那兒', '都', '不', '想', '去'],
#  ['那', '都', '不', '想', '去'],
#  ['且', '很', '不', '想', '動'],
#  ['不', '想', '動', '也', '不', '想', '說'],
#  ['心情', '沮喪', '不', '想', '上班'],
#  ['情緒', '低落', '不', '想', '做', '實驗'],
#  ['我', '就', '開始', '不', '想', '上班'],
#  ['我', '發現', '我', '不', '想', '工作'],
#  ['心情', '沮喪', '不', '想', '上班'],
#  ['不', '喜歡', '也', '不', '想', '去', '學校'],
#  ['電視', '也', '不', '想', '看'],
#  ['不', '想', '做', '事'],
#  ['不', '想', '做', '任何', '事'],
#  ['什麼', '都', '不', '想', '理會'],
#  ['什麼', '都', '不', '想', '參與'],
#  ['我', '整', '個人', '覺得', '懶洋洋'],
#  ['現在', '卻', '懶', '了', '也', '累', '了'],
#  ['常常', '有', '工作', '上', '的', '無力感'],
#  ['經常', '覺得', '有', '一', '種', '無力感'],
#  ['沒有', '活力'],
#  ['總是', '缺乏', '活力'],
#  ['覺得', '自己', '很', '無', '活力'],
#  ['但是', '常常', '覺得', '有氣無力'],
#  ['但', '我', '常', '覺得', '有', '種', '無力感'],
#  ['每', '天', '都', '很', '無力'],
#  ['我', '感到', '無力', '想', '放棄'],
#  ['總', '覺得', '很', '無力感'],
#  ['搞', '的', '現在', '沒有', '活力'],
#  ['整', '個', '人', '沒', '什麼', '活力'],
#  ['對', '什麼', '都', '提', '不', '起勁'],
#  ['而且', '工作', '時', '也', '提', '不', '起勁'],
#  ['但', '就是', '提', '不', '起勁', '去', '做'],
#  ['提', '不', '起勁', '來', '做', '任何', '事'],
#  ['對', '一切', '缺乏', '興趣'],
#  ['沒有', '任何', '的', '興趣'],
#  ['而且', '是', '一點', '興趣', '都', '沒有'],
#  ['但', '老', '提', '不', '起勁'],
#  ['對', '任何', '事', '都', '提', '不', '起勁'],
#  ['而且', '生活', '總是', '提', '不', '起勁'],
#  ['我', '愈來愈', '提', '不', '起勁', '開口', '說話'],
#  ['對', '什麼', '都', '沒有', '興趣'],
#  ['對', '任何', '事', '感到', '沒有', '任何', '興趣'],
#  ['對', '生活', '失去', '興趣'],
#  ['我', '對', '很多', '事物', '無', '興趣'],
#  ['對', '任何', '事', '都', '沒', '興趣'],
#  ['我', '對', '什麼', '都', '沒有', '興趣'],
#  ['對', '所有', '事物', '失去', '興趣'],
#  ['對', '所有人', '或', '事', '失去', '興趣'],
#  ['對', '什麼', '人', '事物', '都', '不再', '感興趣'],
#  ['對', '任何', '事', '沒', '興趣', '沒', '力氣'],
#  ['想', '溫習', '的', '話', '偏', '沒有', '心情'],
#  ['想', '玩', '遊戲', '但', '也', '沒', '心情'],
#  ['想', '溫習', '但', '也', '沒', '心情'],
#  ['擔心', '別人', '的', '事'],
#  ['擔心', '這', '擔心', '那'],
#  ['擔心', '會', '因此', '失去', '工作'],
#  ['我', '很', '擔心', '當兵'],
#  ['我', '真的', '好', '擔心', '他'],
#  ['我', '很', '擔心', '他', '的', '體重'],
#  ['很', '擔心', '再下去', '無法', '正常', '生活'],
#  ['小孩', '功課', '擔心'],
#  ['婆婆', '態度', '也', '擔心'],
#  ['每', '天', '都', '擔心', '自己', '會', '死'],
#  ['從此', '每每', '擔心', '上課', '怎麼辦'],
#  ['擔心', '自己', '會', '失去', '自己'],
#  ['擔心', '自己', '會', '變成', '聯想', '的', '人'],
#  ['但', '擔心', '意外', '發生'],
#  ['一', '邊', '擔心', '將來', '會', '依賴', '成性'],
#  ['我', '最', '擔心', '的', '還是', '復發'],
#  ['時時刻刻', '擔心', '自己', '會', '死去'],
#  ['或者', '擔心', '會', '發生', '什麼', '事'],
#  ['我', '好', '擔心', '這樣', '的', '自己'],
#  ['我', '甚至', '擔心', '她', '會', '想不開'],
#  ['入睡', '前', '頻尿', '純粹', '是', '擔心', '睡', '不', '著'],
#  ['我', '不', '擔心', '我', '的', '爸媽'],
#  ['也', '擔心', '自己', '的', '未來'],
#  ['擔心', '好多', '事'],
#  ['晚上', '一直', '擔心', '會不會', '睡著'],
#  ['因', '開刀', '前', '擔心', '將來', '無法', '生育'],
#  ['擔心', '自己', '有的', '現象'],
#  ['我', '好', '擔心', '我', '沒有', '未來'],
#  ['擔心', '作業', '交', '不', '出來'],
#  ['擔心', '沒', '工作', '怎麼辦'],
#  ['但', '我', '還是', '擔心', '會不會', '好'],
#  ['擔心', '我', '會', '口吃'],
#  ['我', '知道', '擔心', '他們', '也', '沒有用'],
#  ['更', '憂慮', '死', '後', '沒有', '天堂'],
#  ['我', '又', '有', '新', '問題', '擔憂', '了'],
#  ['並且', '嚴重', '憂慮', '影響', '生息'],
#  ['然而', '最多', '的', '是', '茫然', '和', '擔憂'],
#  ['常', '會', '突然', '感到', '憂慮'],
#  ['原因', '是', '很', '容易', '憂心'],
#  ['但', '現在', '我', '就是', '整天', '在', '擔心'],
#  ['我', '會', '擔心'],
#  ['我', '也', '同樣', '擔心'],
#  ['我', '很', '擔心'],
#  ['我', '又', '開始', '擔心'],
#  ['我', '是', '不', '是', '太', '容易', '過度', '擔心', '咧'],
#  ['我', '真的', '非常', '非常', '擔心'],
#  ['心', '中', '很', '擔心'],
#  ['一', '緊張', '起來', '就', '會', '臉紅'],
#  ['常常', '顯', '的', '很', '緊張'],
#  ['焦慮', '急躁'],
#  ['然後', '好像', '心理', '作用', '的', '緊張', '起來'],
#  ['且', '當', '我', '一', '緊張', '害怕', '時'],
#  ['我', '會', '容易', '緊張'],
#  ['不會', '有', '緊張', '的', '感覺'],
#  ['其實', '我', '很', '生氣'],
#  ['我', '就', '會', '焦慮', '得', '睡不著覺'],
#  ['好像', '憂鬱', '又', '像', '焦慮'],
#  ['可以', '說', '是', '一', '個', '緊張', '大師'],
#  ['一', '緊張', '就', '心臟', '跳', '很', '快'],
#  ['但', '遇到', '什麼', '事', '仍舊', '緊張'],
#  ['會', '嚇到', '同學', '而', '覺得', '不安'],
#  ['它', '讓', '我', '很', '害怕', '很', '不安'],
#  ['同時', '易', '緊張'],
#  ['同時', '又', '不會', '因', '緊張', '而', '發作'],
#  ['我', '有', '幾', '個', '問題', '令', '我', '不安'],
#  ['還', '有', '緊張', '的', '時候'],
#  ['緊張', '的', '時候', '肩膀', '緊繃'],
#  ['還是', '緊張', '壓力', '所', '造成', '的'],
#  ['我', '為之', '不安', '至今'],
#  ['人', '不再', '那麼', '緊張', '了'],
#  ['也', '令', '我', '感到', '很', '不安'],
#  ['然後', '陷入', '不安'],
#  ['使得', '我', '的', '心', '裡', '十分', '緊張'],
#  ['心情', '非常', '緊張'],
#  ['感到', '焦慮'],
#  ['總是', '很', '緊張'],
#  ['就是', '時常', '緊張', '導致', '於', '臉紅'],
#  ['而', '導致', '緊張'],
#  ['說到', '我', '都', '越來越', '緊張'],
#  ['尤其', '是', '在', '我', '焦慮'],
#  ['我', '就', '會', '異常', '地', '興奮', '與', '緊張'],
#  ['但', '越', '呼', '越', '緊張'],
#  ['心', '裡', '還是', '很', '不安'],
#  ['我', '也', '是', '一樣', '的', '感到', '不安'],
#  ['不然', '會', '整', '天', '無緣無故', '焦慮'],
#  ['且', '有', '焦慮'],
#  ['但', '我', '就是', '會', '緊張', '害怕'],
#  ['一', '整', '天', '都', '會', '覺得', '很', '緊張'],
#  ['我', '就是', '會', '緊張'],
#  ['為何', '會', '變得', '很', '容易', '緊張'],
#  ['由', '最初', '的', '焦慮症', '至', '憂鬱症'],
#  ['我', '的', '心', '就', '開始', '焦慮', '不安'],
#  ['而且', '他', '很', '容易', '緊張'],
#  ['就', '會', '不自覺', '的', '緊張'],
#  ['他', '說', '他', '也', '會', '緊張', '而', '不知所措'],
#  ['從此', '進入', '那', '家', '理髮店', '就', '會', '緊張'],
#  ['會', '緊張', '害羞', '內向'],
#  ['會', '感到', '緊張'],
#  ['似', '初次', '發病', '時', '焦躁', '現象'],
#  ['我', '心', '裡', '更加', '不安'],
#  ['就', '會', '感到', '緊張'],
#  ['也', '會', '緊張', '地', '手部', '發抖'],
#  ['極度', '不安'],
#  ['恐懼', '不安'],
#  ['又', '對於', '軟弱', '的', '自己', '感到', '生氣'],
#  ['跟', '人', '接觸', '時', '我', '會', '緊張'],
#  ['醒來', '會', '難過', '和', '焦慮', '不安'],
#  ['但', '焦慮', '還是', '一樣'],
#  ['憂心', '沖沖'],
#  ['就', '會', '覺得', '非常', '焦慮'],
#  ['我', '就', '開始', '緊張'],
#  ['通常', '會', '緊張', '一', '整', '天'],
#  ['一', '緊張', '就', '會', '心跳', '加快'],
#  ['我', '很', '容易', '緊張'],
#  ['但是', '卻', '有', '容易', '緊張', '的', '毛病'],
#  ['可是', '不', '做', '我', '又', '會', '不安'],
#  ['所以', '當成', '自己', '是', '在', '窮', '緊張'],
#  ['自己', '也', '相當', '焦慮'],
#  ['有時候', '莫名其妙', '的', '就', '感到', '焦慮'],
#  ['我', '容易', '緊張'],
#  ['曾', '有', '幾', '次', '因為', '考試', '緊張'],
#  ['本', '就', '較', '容易', '緊張', '個', '個性'],
#  ['常', '會', '緊張', '到', '自己', '有點', '受不了'],
#  ['我', '會', '緊張'],
#  ['我', '就', '會', '緊張'],
#  ['就', '會', '表情', '緊張'],
#  ['而且', '我', '看到', '醫生', '會', '緊張'],
#  ['有時候', '還', '會', '緊張', '過度'],
#  ['導致', '個', '人', '緊張'],
#  ['焦躁', '不安'],
#  ['很', '浮躁', '不安'],
#  ['那會', '讓', '他', '緊張'],
#  ['我', '更', '是', '會', '緊張', '神經質'],
#  ['尤其', '是', '緊張', '的', '時候'],
#  ['在', '那', '當下', '完全', '只', '有', '緊張'],
#  ['我', '緊張', '個', '什麼', '勁'],
#  ['感到', '非常', '不安'],
#  ['每', '次要', '睡覺', '都', '好', '緊張'],
#  ['常', '感覺到', '不安'],
#  ['常', '覺得', '得', '急躁'],
#  ['整', '天', '精神', '處於', '緊繃'],
#  ['容易', '緊張', '造成', '腸胃', '不好'],
#  ['常', '覺得', '活', '得', '很', '緊張', '壓力', '很', '大'],
#  ['而且', '最近', '伴隨', '著', '焦慮'],
#  ['時常', '感到', '焦慮'],
#  ['我', '每', '天', '上課', '都', '非常', '緊張'],
#  ['我', '就', '非常', '不安'],
#  ['就', '讓', '自已', '越來越', '緊張'],
#  ['就', '非常', '焦慮'],
#  ['緊張', '時', '還', '會', '更', '嚴重'],
#  ['更', '是', '讓', '我', '緊張', '的', '快', '窒息'],
#  ['可能', '是', '太', '緊張', '的', '緣', '固'],
#  ['我', '也', '會', '有', '莫名', '的', '緊張'],
#  ['很', '容易', '緊張'],
#  ['因', '伯父', '現在', '極', '易', '緊張'],
#  ['偶', '焦慮', '不安'],
#  ...]
